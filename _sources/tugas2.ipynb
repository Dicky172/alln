# %% [markdown]
# #Aljabar Matriks

# %%
import numpy as np
import sympy as sy

# %% [markdown]
# #Matriks 3x3

# %%
a = np.array ([[1,2,3],[2,3,1],[2,4,3]])
print(a)
# Out:
# [[1 2 3]
#  [2 3 1]
#  [2 4 3]]

# %% [markdown]
# #matriks 3x2

# %%
b = np.array([[5,4,6],[1,3,2]])
print(b)
# Out:
# [[5 4 6]
#  [1 3 2]]

# %% [markdown]
# #matriks 3x2

# %%
c = np.array([[5,6],[4,3],[7,8]])
print(c)
# Out:
# [[5 6]
#  [4 3]
#  [7 8]]

# %% [markdown]
# #matriks d 3x3

# %%
d = np.array([[4,3,5],[2,3,1],[7,6,5]])
print(d)
# Out:
# [[4 3 5]
#  [2 3 1]
#  [7 6 5]]

# %% [markdown]
# nxn matriks a
# bxn matriks b
